# %% [markdown]
# ![gradient-descent-convergence.gif](attachment:gradient-descent-convergence.gif)
# ### <center>Convergência (comportamento esperado)</center>
#
#
# <br><br>
# ![gradient-descent-divergence.gif](attachment:gradient-descent-divergence.gif)
# ### <center>Divergência (taxa de aprendizagem (learning_rate) muito alta)</center>

# %%
def gradient_descent_update(x, gradx, learning_rate):
    """
    Performs a gradient descent update.
    """
    # TODO: Implement gradient descent.
    
    # Return the new value for x
    return x - learning_rate * gradx

# %%
"""
Given the starting point of any `x` gradient descent
should be able to find the minimum value of x for the
cost function `f` defined below.
"""
import random


def f(x):
    """
    Quadratic function.

    It's easy to see the minimum value of the function
    is 5 when is x=0.
    """
    return x**2 + 5


def df(x):
    """
    Derivative of `f` with respect to `x`.
    """
    return 2*x


# Random number between 0 and 10,000. Feel free to set x whatever you like.
x = random.randint(0, 10000)
# TODO: Set the learning rate
learning_rate = 0.0001
epochs = 100

for i in range(epochs+1):
    cost = f(x)
    gradx = df(x)
    print("EPOCH {}: Cost = {:.3f}, x = {:.3f}".format(i, cost, gradx))
    x = gradient_descent_update(x, gradx, learning_rate)
# Out:
# EPOCH 0: Cost = 87984405.000, x = 18760.000
# EPOCH 1: Cost = 87949214.759, x = 18756.248
# EPOCH 2: Cost = 87914038.593, x = 18752.497
# EPOCH 3: Cost = 87878876.497, x = 18748.746
# EPOCH 4: Cost = 87843728.463, x = 18744.997
# EPOCH 5: Cost = 87808594.487, x = 18741.248
# EPOCH 6: Cost = 87773474.564, x = 18737.499
# EPOCH 7: Cost = 87738368.687, x = 18733.752
# EPOCH 8: Cost = 87703276.851, x = 18730.005
# EPOCH 9: Cost = 87668199.051, x = 18726.259
# EPOCH 10: Cost = 87633135.280, x = 18722.514
# EPOCH 11: Cost = 87598085.533, x = 18718.769
# EPOCH 12: Cost = 87563049.805, x = 18715.025
# EPOCH 13: Cost = 87528028.089, x = 18711.282
# EPOCH 14: Cost = 87493020.381, x = 18707.540
# EPOCH 15: Cost = 87458026.675, x = 18703.799
# EPOCH 16: Cost = 87423046.964, x = 18700.058
# EPOCH 17: Cost = 87388081.244, x = 18696.318
# EPOCH 18: Cost = 87353129.509, x = 18692.579
# EPOCH 19: Cost = 87318191.754, x = 18688.840
# EPOCH 20: Cost = 87283267.972, x = 18685.102
# ...
